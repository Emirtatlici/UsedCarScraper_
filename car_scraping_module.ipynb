# %%
import pandas as pd
pd.set_option("display.max_column",105)

# %% [markdown]
# ## Importing the module

# %%
from UsedCarScraper import CarSearch
car_scraper=CarSearch()

# %% [markdown]
# ## Data Scraping Structure

# %%
data=car_scraper.search_cars()
# Out:
# Enter search parameters:
#
# Entered search parameters:
# Number of Pages: 10
# Brand Name:BMW
# Body Style: Sedan
# Maximum price: 39999
# Maximum mileage: 60000
# Minimum year: 2015
# Maximum year: 2024
# ZIP Code: 90001
#
# Searching...
# INFO:UsedCarScraper:Page 1 scraped. 9 pages left.
# INFO:UsedCarScraper:Page 2 scraped. 8 pages left.
# INFO:UsedCarScraper:Page 3 scraped. 7 pages left.
# INFO:UsedCarScraper:Page 4 scraped. 6 pages left.
# INFO:UsedCarScraper:Page 5 scraped. 5 pages left.
# INFO:UsedCarScraper:Page 6 scraped. 4 pages left.
# INFO:UsedCarScraper:Page 7 scraped. 3 pages left.
# INFO:UsedCarScraper:Page 8 scraped. 2 pages left.
# INFO:UsedCarScraper:Page 9 scraped. 1 pages left.
# INFO:UsedCarScraper:Page 10 scraped. 0 pages left.

# %%
data.head()
# Out:
#           id  chrome_trim_id  year make     model  trim             city  \
# 0  282923422          406196  2020  BMW  7 Series  740i        La Puente
# 1  282923462          402237  2019  BMW  5 Series  540i        La Puente
# 2  282923437          402237  2019  BMW  5 Series  540i        La Puente
# 3  279272742          436933  2024  BMW  4 Series  430i  Rowland Heights
# 4  274969580          436933  2024  BMW  4 Series  430i  Rowland Heights
#
#   state  dealer_id  dealer_radius partner_code  partner_priority date_listed  \
# 0    CA    2608841             30           lx                 1  2024-05-18
# 1    CA    2608841             30           lx                 1  2024-05-18
# 2    CA    2608841             30           lx                 1  2024-05-18
# 3    CA      11706             60           tc                 2  2024-04-27
# 4    CA      11706             60           tc                 2  2024-04-06
#
# ...

# %% [markdown]
# ## Save the data to an excel file

# %%
car_scraper.save_to_excel("scraped_data.xlsx")
# Out:
# INFO:UsedCarScraper:Data saved to scraped_data.xlsx
